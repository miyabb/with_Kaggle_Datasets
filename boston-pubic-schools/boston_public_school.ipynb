# %%
import pandas as pd

df = pd.read_csv('Public_Schools.csv')

# %%
df
# Out:
#              X          Y  OBJECTID_1  OBJECTID  BLDG_ID  \
# 0   -71.004121  42.388799           1         1        1
# 1   -71.030480  42.378545           2         2        3
# 2   -71.033891  42.375279           3         3        4
# 3   -71.038011  42.378089           4         4        6
# 4   -71.034921  42.380957           5         5        7
# 5   -71.040330  42.378290           6         6        8
# 6   -71.034120  42.369676           7         7       10
# 7   -71.034308  42.369274           8         8       11
# 8   -71.034890  42.365563           9         9       12
# 9   -71.057492  42.376629          10        10       13
# 10  -71.061071  42.380119          11        11       14
# 11  -71.067231  42.379080          12        12       15
# 12  -71.064431  42.377999          13        13       16
# 13  -71.053370  42.366103          14        14       17
# 14  -71.069050  42.348408          15        15       21
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID_1', 'OBJECTID', 'BLDG_ID', 'BLDG_NAME', 'ADDRESS',
#        'CITY', 'ZIPCODE', 'CSP_SCH_ID', 'SCH_ID', 'SCH_NAME', 'SCH_LABEL',
#        'SCH_TYPE', 'SHARED', 'COMPLEX', 'Label', 'TLT', 'PL', 'POINT_X',
#        'POINT_Y'],
#       dtype='object')
